# %%
from time import time
from datetime import datetime
import numpy as np
def multiply(A,B):
    return [a*b for a,b in zip(A,B)]
def divide(A,B):
    return [a/b for a,b in zip(A,B)]

def minus(A,B):
    return [a-b for a,b in zip(A,B)]
def log(txt):
    f= open("log2.txt","a+")
    f.write('%s: %s \r\n'%(datetime.now().strftime('{%Y-%m-%d %H:%M:%S}'),txt))
    print(txt)
    f.close() 
def initial_log():
    f= open("log2.txt","w+")
    f.write('%s: starting.... \r\n'%(datetime.now().strftime('{%Y-%m-%d %H:%M:%S}')))
    f.close() 
import pickle
def savedf():
    with open('df2.dat','wb') as f:
        pickle.dump((X_train, X_test, y_train, y_test),f)

def loaddf():
    global X_train, X_test, y_train, y_test
    with open('df2.dat','rb') as f:
        X_train, X_test, y_train, y_test = pickle.load(f)

        
def save():
    with open('data2.dat','wb') as f:
        pickle.dump((i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse),f)
def load():
    global i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse
    with open('data2.dat','rb') as f:
        i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse = pickle.load(f)

def load1():
    global i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse
    with open('data1.dat','rb') as f:
        i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse = pickle.load(f)
import os
os.environ["PATH"] += os.pathsep +"C:\\Users\\User\\Downloads\\graphviz-2.38\\release\\bin"

# %%
from numpy import var

class Splitter:
    def __init__(self,X,Y):
        self.X = X
        self.Y = Y

    def split(self,index,value):
        """ 
        Split X and Y based on the given variable index and value
  
        Parameters: 
            index (int): index of variable to splitted on
            value (float): the value of splitting varaible
          
        Returns: 
            right_x,left_x,rigth_y,left_y
        """
        right_x = [x for x in self.X if x[index]>=value]
        left_x = [x for x in self.X if x[index]<value]
        
        right_y = [self.Y[i] for i,x in enumerate(self.X) if x[index]>=value]
        left_y = [self.Y[i] for i,x in enumerate(self.X) if x[index]<value]
        return right_x,left_x,right_y,left_y
    
    def weighted_var(self,Y):
        if len(Y) ==0:
            return float('inf')
        return var(Y)/len(Y)
    
    def SE(self,Y):
        if len(Y) ==0: return float('inf')
        mean = sum(Y)/len(Y)
        SE = sum([(y-mean)**2 for y in Y])
        return SE
        
    
    def splitting_cost(self,right_x,left_x,right_y,left_y):
        """ 
        Compute cost of spliting.
        in the current version, we have used varaince based cost function
  
        Parameters: 
            right_x,left_x,rigth_y,left_y
          
        Returns: 
            float: the cost of computing
        """        
        return (self.SE(right_y)+self.SE(left_y))/(len(right_y)+len(left_y))
    
    def possibleValues(self,index):
        values = [x[index] for x in self.X]
        values.sort()
        max_values = 100
        if len(values)<max_values:
            return values
        
        return set([np.percentile(values,i*100//max_values) for i in range(max_values)])
    
    def test_splitting(self,index,value):
        right_x,left_x,right_y,left_y = self.split(index,value)
        return  self.splitting_cost(right_x,left_x,right_y,left_y),len(right_y),len(left_y)
    
    def find_best_splitting(self,min_leaf_treshold=30,min_split=70):
        """ 
        Find best splitting and return index and value of splitting variable respectively
       
        Returns: 
            int,float: the index and value of best possible splitting variables
        """ 
        
        best_splitting = (self.SE(self.Y)/len(self.Y))
        best_splitting_index = -1
        best_splitting_value = 0
        if len(self.Y)<min_split:
            return best_splitting_index,best_splitting_value            
        for index in range(len(self.X[0])):
            for value in self.possibleValues(index):
                splitting_cost,left_cnt,right_cnt = self.test_splitting(index,value)
#               print('splitting at %f: cost->%f'%(value,splitting_cost))
                if splitting_cost < best_splitting and left_cnt >= min_leaf_treshold and right_cnt >= min_leaf_treshold:
                    best_splitting = splitting_cost
                    best_splitting_index = index
                    best_splitting_value = value
        return best_splitting_index,best_splitting_value

# %%
id = 0
last_leaf_no = 1
def create_Tree():
    global last_leaf_no
    last_leaf_no = 1
    return Node(0)
class Node:
    isLeaf = True
    Left = None
    Right = None
    Value = None
    Depth = 0
    splitting_var_index = 0
    splitting_value = 0
    cnt = 0
    
    
    def __init__(self,depth):
        global id
        id+=1
        self.ID = id
        self.isLeaf = True
        self.Depth = depth
    def predict(self,X):
        return [self.predict_one(x) for x in X]
        
    def predict_one(self,X):
        if type(X) != list:
            raise TypeError("predict_one.X: expected list but recieved %s (%s)"%(X,type(X)))
        try:
            if self.isLeaf:
                self.cnt +=1
                return self.Value
            if X[self.splitting_var_index] >= self.splitting_value:
                return self.Right.predict_one(X)
            else:
                return self.Left.predict_one(X)
        except IndexError:
            print('index: %i'%self.splitting_var_index)
            raise
    
    
    def fit(self,X,Y,max_depth):
        global last_leaf_no

        #tree reached maximum depth
        if max_depth <= self.Depth:
            self.isLeaf = True
            self.leafID = last_leaf_no
            last_leaf_no+=1
            self.fit_leaf_value(Y)
            return 
        
        #continue splitting if more depth allowed
        splitter = Splitter(X,Y)
        best_splitting_index,best_splitting_value = splitter.find_best_splitting()
        if best_splitting_index == -1:
            #better to not split
            self.isLeaf = True
            self.leafID = last_leaf_no
            last_leaf_no+=1
            self.fit_leaf_value(Y)
        else:
            right_x,left_x,right_y,left_y = splitter.split(best_splitting_index,best_splitting_value)
            self.isLeaf = False
            self.splitting_var_index = best_splitting_index
            self.splitting_value = best_splitting_value
            self.Right = Node(self.Depth+1)
            self.Left = Node(self.Depth+1)
            self.Right.fit(right_x,right_y,max_depth)
            self.Left.fit(left_x,left_y,max_depth)
    def fit_leaf_value(self,Y):
        self.Value = sum(Y)/len(Y)

        
    def tune(self,X,R,T):
        self.X = X
        self.Y = ['%f:%f'%(r,t) for r,t in zip(R,T)]
        if len(X) != len(R):
            raise TypeError("tune function: X and R should be with same size. recieved <%i>.<%i>"%(len(X),len(R)))
        if len(X) != len(T):
            raise TypeError("tune function: X and T should be with same size. recieved <%i>.<%i>"%(len(X),len(T)))
            
        if self.isLeaf:
            if sum(multiply(T,T)) == 0:
                self.value = 1
            else:
                self.Value = sum(multiply(R,T))/sum(multiply(T,T))
            return
        
        splitter = Splitter(X,R)
        right_x,left_X,right_R,left_R = splitter.split(self.splitting_var_index,self.splitting_value)
        splitter = Splitter(X,T)
        right_x,left_X,right_T,left_T = splitter.split(self.splitting_var_index,self.splitting_value)
        self.Right.tune(right_x,right_R,right_T)
        self.Left.tune(left_X,left_R,left_T)
        
    def draw_tree(self):
        from graphviz import Source
        from io import BytesIO
        from matplotlib import pyplot as plt
        from matplotlib import image
        g = Source('digraph {\n\tgraph [rankdir=UT]\n'+self.print_tree()+'}')
        g.render('round-table.gv', view=True)
        #return img
        
    def get_leafcounts(self):
        if self.isLeaf:
            return 1
        return self.Left.get_leafcounts()+self.Right.get_leafcounts()
    
    def print_tree(self,prefix=''):
        '\t0 [label="f0<8.40779079e-45] yes=1,no=2,missing=1\n\t1:[f0<2.80259693e-45] yes=3,no=4,missing=3\n\t\t3:leaf=7.46349096\n\t\t4:leaf=-0.278686523\n\t2:[f0<8.40779079e-45] yes=5,no=6,missing=5\n\t\t5:leaf=-0\n\t\t6:leaf=-0.188493282\n'
        if not self.isLeaf:
            ret = '\t%i [label="f%i>=%f"]\n\t%i -> %i [label="yes" color="#0000FF"]\n\t %i -> %i [label=no color="#FF0000"]\n'%(
                self.ID,self.splitting_var_index,self.splitting_value,self.ID,self.Right.ID,self.ID,self.Left.ID)
            ret += self.Right.print_tree(prefix+'\t')
            ret += self.Left.print_tree(prefix+'\t')
            return ret
        else:
            return '\t%i [label="leaf=%f\nCount=%i"]\n'%(self.ID,self.Value,self.cnt)
    def get_leaf_values(self):
        if self.isLeaf:
            return [self.Value]
        return self.Right.get_leaf_values()+self.Left.get_leaf_values()
    
'''digraph {
	graph [rankdir=UT]
	0 [label="f0<8.40779079e-45"]
	0 -> 1 [label="yes, missing" color="#0000FF"]
	0 -> 2 [label=no color="#FF0000"]
	1 [label="f0<2.80259693e-45"]
	1 -> 3 [label="yes, missing" color="#0000FF"]
	1 -> 4 [label=no color="#FF0000"]
	3 [label="leaf=7.46349096"]
	4 [label="leaf=-0.278686523"]
	2 [label="f0<8.40779079e-45"]
	2 -> 5 [label="yes, missing" color="#0000FF"]
	2 -> 6 [label=no color="#FF0000"]
	5 [label="leaf=-0"]
	6 [label="leaf=-0.188493282"]
}'''
# Out:
# 'digraph {\n\tgraph [rankdir=UT]\n\t0 [label="f0<8.40779079e-45"]\n\t0 -> 1 [label="yes, missing" color="#0000FF"]\n\t0 -> 2 [label=no color="#FF0000"]\n\t1 [label="f0<2.80259693e-45"]\n\t1 -> 3 [label="yes, missing" color="#0000FF"]\n\t1 -> 4 [label=no color="#FF0000"]\n\t3 [label="leaf=7.46349096"]\n\t4 [label="leaf=-0.278686523"]\n\t2 [label="f0<8.40779079e-45"]\n\t2 -> 5 [label="yes, missing" color="#0000FF"]\n\t2 -> 6 [label=no color="#FF0000"]\n\t5 [label="leaf=-0"]\n\t6 [label="leaf=-0.188493282"]\n}'

# %%
    from copy import deepcopy
    from sklearn.metrics import mean_squared_error
    from math import sqrt


    class FractBoosting:

        def __init__(self,learning_rate):
            self.learning_rate = learning_rate
            self.trees = []

        def predict(self,X):
            Y = []
            for x in X:
                predictions = [S.predict([x])[0]*T.predict([x])[0] for S,T in self.trees]
                predict = predictions[0] + self.learning_rate*sum(predictions[1:])
                Y.append(predict)

            return Y

        def fit(self,X,Y,max_depth,max_trees):
            """ 
            Fit the boosting trees on the given data

            Parameters: 
                X (list of list): the input X
                Y (list): input Y
                max_depth (int): maximum depth of trees
                max_trees (int): the number of trees
            """ 

            lastRMSE = self.rmse(X,Y)
            improvment = []
            for i in range(1,max_trees):
                t0 = time()
                depth = int(1+max_depth*sqrt(i/max_trees))
                log('starting itteration %i with depth %i'%(i,depth))
    #            print('itteration %i, begining, mean loss: %f, tree depth: %i'%(i,self.rmse(X,Y),depth))
                self.fit_one_step(X,Y,depth)

                current_rmse = self.rmse(X,Y)
                RMSEDif = lastRMSE - current_rmse
                lastRMSE = current_rmse
                cost = T.get_leafcounts()
                imp = cost/RMSEDif
                improvment.append(imp)
                log('itteration %i done in %0.3fs, RMSE: %f, Cost/improvement: %f'%(i,time() - t0,current_rmse,imp))
            return improvment
        def create_root_tree(self,Y):
            root_s = create_Tree()
            root_s.Value = 1
            root_t = create_Tree()
            root_t.fit_leaf_value(Y)
            self.trees = [(root_s,root_t)]

        def fit_one_step(self,X,Y,depth):
            Y_r = self.get_residual(X,Y)
            T = create_Tree()
            T.fit(X,Y_r,depth)
            Y_t = T.predict(X)
            S = deepcopy(self.trees[-1][1])
            S.tune(X,Y_r,Y_t)
            self.trees.append((S,T))
        def get_residual(self,X,Y):
            h = self.predict(X)
            Y_r = minus(Y , h)
            return Y_r
        def print_trees(self):
            for i,(s,t) in enumerate(self.trees):
                print('%ith fractal tree\n'%i)
                print('-----------------\n')
                print('S:\n')
                s.print_tree()
                print('-----------------\n')
                print('T:\n')
                t.print_tree()
                print('\n-----------------\n')

        def rmse(self,X,Y):
            h = self.predict(X)
    #        R = minus(Y , h)
    #        print('Residual:',R)
            return sqrt(mean_squared_error(h, Y))

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
df_train = pd.read_csv('Sydney_Data.csv',header=None)
df_train.head() 
X = df_train.loc[:,0:41].values.tolist()
Y = df_train[42].values.tolist()
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.4)
print('train size:%i, test size:%i, var:%i'%(len(X_train),len(X_test),len(X_train[0])))
savedf()
# Out:
# train size:43200, test size:28800, var:42

# %%
from numpy import std
import xgboost as xgb
from threading import Thread
from xgboost import plot_tree
from sklearn.metrics import mean_squared_error
max_depth=5

loaddf()
#initial_log()
mdl_1 = FractBoosting(.1)
mdl_2 = FractBoosting(.1)
mdl_3 = FractBoosting(.1)
mdl_1.create_root_tree(y_train)
mdl_2.create_root_tree(y_train)
mdl_3.create_root_tree(y_train)
last_rmse = mdl_3.rmse(X_train,y_train)
last_depth = 1

m = sum(y_train)/len(y_train)
y_train_xgb = [y-m for y in y_train]

RMSETest = [[],[],[],[],[],[]]
RMSETrain =  [[],[],[],[],[],[]]
i=0
try:
    load()
except Exception as e:
    print(e)
    initial_log()
if len(RMSETest) < 6:
    RMSETest.append([])
    RMSETest.append([])
    RMSETrain.append([])
    RMSETrain.append([])
try:
    while i<200:
        processes = []




        ################Fixed depth
        mdl_1.fit_one_step(X_train,y_train,max_depth)
        RMSETrain[0].append( mdl_1.rmse(X_train,y_train))
        RMSETest[0].append( mdl_1.rmse(X_test,y_test))    
        print('Fixed depth')


        
        ###############Linear depth
        depth = min(5,int(1+max_depth*(i/50)))
        mdl_2.fit_one_step(X_train,y_train,depth)    
        RMSETrain[1].append( mdl_2.rmse(X_train,y_train))
        RMSETest[1].append( mdl_2.rmse(X_test,y_test))    
        print('Linear depth')


        ###############dynamic depth
        mdl_3.fit_one_step(X_train,y_train,last_depth)
        mdl3_rmse = mdl_3.rmse(X_test,y_test)
        RMSETrain[2].append( mdl_3.rmse(X_train,y_train))
        RMSETest[2].append( mdl_3.rmse(X_test,y_test))
        print('dynamic depth')
        


        ##################XGBoost
        xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                        max_depth = 5,  n_estimators = i)
        xg_reg.fit(X_train,y_train_xgb)    
        preds = xg_reg.predict(X_train)
        RMSETrain[3].append(np.sqrt(mean_squared_error(y_train, [p+m for p in preds])))
        preds = xg_reg.predict(X_test)
        RMSETest[3].append(np.sqrt(mean_squared_error(y_test, [p+m for p in preds])))
        print('XGB')
        
        xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                        max_depth = 1,  n_estimators = i)
        xg_reg.fit(X_train,y_train_xgb)    
        preds = xg_reg.predict(X_train)
        RMSETrain[4].append(np.sqrt(mean_squared_error(y_train, [p+m for p in preds])))
        preds = xg_reg.predict(X_test)
        RMSETest[4].append(np.sqrt(mean_squared_error(y_test, [p+m for p in preds])))
        
                
        xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                        max_depth = 2,  n_estimators = i)
        xg_reg.fit(X_train,y_train_xgb)    
        preds = xg_reg.predict(X_train)
        RMSETrain[5].append(np.sqrt(mean_squared_error(y_train, [p+m for p in preds])))
        preds = xg_reg.predict(X_test)
        RMSETest[5].append(np.sqrt(mean_squared_error(y_test, [p+m for p in preds])))
        
        print('XGB')
        i+=1
        
        save()
                           
        log('\r\n-----------------------------------------------\r\n'+
            'ittr %i \tTrain\t\tTest\t\tDiff\t\tRVar\tSVar\tTVar\r\n'%i+
            'FGB[%i]:\t%.2f\t\t%.2f\t\t%.2f\t\t%.1f\t%.1f\t\t%.1f\r\n'%(max_depth,RMSETrain[0][-1],RMSETest[0][-1],RMSETest[0][-1]-RMSETrain[0][-1],std(mdl_1.get_residual(X,Y)),std(mdl_1.trees[-1][0].get_leaf_values()),std(mdl_1.trees[-1][1].get_leaf_values()))+
            'FGB[%i]:\t%.2f\t\t%.2f\t\t%.2f\t\t%.1f\t%.1f\t\t%.1f\r\n'%(depth,RMSETrain[1][-1],RMSETest[1][-1],RMSETest[1][-1]-RMSETrain[1][-1],std(mdl_2.get_residual(X,Y)),std(mdl_2.trees[-1][0].get_leaf_values()),std(mdl_2.trees[-1][1].get_leaf_values()))+
            'FGB[%i]:\t%.2f\t\t%.2f\t\t%.2f\t\t%.1f\t%.1f\t\t%.1f\r\n'%(last_depth,RMSETrain[2][-1],RMSETest[2][-1],RMSETest[2][-1]-RMSETrain[2][-1],std(mdl_3.get_residual(X,Y)),std(mdl_3.trees[-1][0].get_leaf_values()),std(mdl_3.trees[-1][1].get_leaf_values()))+
            'XGB[%i]:\t%.2f\t\t%.2f\t\t%.2f \r\n'%(1,RMSETrain[5][-1],RMSETest[5][-1],RMSETest[5][-1]-RMSETrain[5][-1])+
            'XGB[%i]:\t%.2f\t\t%.2f\t\t%.2f \r\n'%(2,RMSETrain[4][-1],RMSETest[4][-1],RMSETest[4][-1]-RMSETrain[4][-1])+
            'XGB[%i]:\t%.2f\t\t%.2f\t\t%.2f \r\n'%(max_depth,RMSETrain[3][-1],RMSETest[3][-1],RMSETest[3][-1]-RMSETrain[3][-1]))

        if (last_rmse/mdl3_rmse)<1.005 and last_depth < max_depth:
            last_depth +=1
        last_rmse = mdl3_rmse

except Exception as e:
    log(e)
    raise
# Out:
# Fixed depth
# Linear depth
# dynamic depth
# [05:13:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [05:14:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:14:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 13 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3805.98		3834.63		28.65		3817.5	0.4		2278.9
# FGB[2]:	4914.79		4898.37		-16.42		4908.2	0.3		2853.7
# FGB[1]:	5214.49		5191.88		-22.60		5205.5	0.1		2413.2
# XGB[1]:	4442.22		4436.64		-5.58
# XGB[2]:	5304.15		5285.50		-18.65
# XGB[5]:	3911.15		3938.28		27.13
#
# Fixed depth
# Linear depth
# dynamic depth
# [05:41:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [05:41:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:41:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 14 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3728.22		3761.23		33.01		3741.5	0.6		1893.4
# FGB[2]:	4765.06		4750.78		-14.28		4759.4	0.4		2455.0
# FGB[1]:	5122.34		5102.96		-19.38		5114.6	0.1		2238.0
# XGB[1]:	4351.52		4347.51		-4.01
# XGB[2]:	5212.06		5192.09		-19.96
# XGB[5]:	3820.10		3852.07		31.97
#
# Fixed depth
# Linear depth
# dynamic depth
# [06:07:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [06:08:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:08:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 15 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3662.00		3699.73		37.73		3677.1	0.5		1692.0
# FGB[2]:	4627.45		4616.33		-11.12		4623.0	1.1		3185.3
# FGB[1]:	5041.73		5020.79		-20.94		5033.4	0.0		2465.1
# XGB[1]:	4266.45		4265.28		-1.16
# XGB[2]:	5121.99		5104.93		-17.06
# XGB[5]:	3741.99		3778.10		36.11
#
# Fixed depth
# Linear depth
# dynamic depth
# [06:34:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [06:35:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:35:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 16 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3602.94		3643.91		40.97		3619.4	0.5		1475.8
# FGB[2]:	4510.32		4499.97		-10.35		4506.2	0.2		2395.9
# FGB[1]:	4962.38		4944.54		-17.84		4955.3	0.1		2207.5
# XGB[1]:	4194.48		4194.47		-0.01
# XGB[2]:	5041.06		5022.50		-18.56
# XGB[5]:	3675.43		3715.62		40.19
#
# Fixed depth
# Linear depth
# dynamic depth
# [07:01:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [07:02:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [07:02:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 17 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3552.55		3596.76		44.21		3570.3	0.6		1547.4
# FGB[2]:	4407.40		4399.09		-8.30		4404.0	0.2		2331.8
# FGB[1]:	4889.61		4870.58		-19.03		4882.0	0.1		1945.4
# XGB[1]:	4127.71		4130.44		2.73
# XGB[2]:	4960.93		4944.44		-16.48
# XGB[5]:	3617.33		3661.20		43.87
#
# Fixed depth
# Linear depth
# dynamic depth
# [07:28:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [07:29:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [07:29:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 18 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3508.37		3556.32		47.95		3527.6	0.5		1643.5
# FGB[2]:	4310.01		4302.15		-7.86		4306.8	2.1		1833.6
# FGB[1]:	4818.36		4803.01		-15.34		4812.2	0.0		1920.4
# XGB[1]:	4072.44		4076.48		4.03
# XGB[2]:	4888.79		4871.07		-17.71
# XGB[5]:	3565.89		3613.37		47.48
#
# Fixed depth
# Linear depth
# dynamic depth
# [07:56:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [07:56:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [07:56:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 19 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3469.18		3520.48		51.31		3489.8	0.7		1547.9
# FGB[2]:	4227.53		4220.88		-6.65		4224.9	0.4		1877.8
# FGB[1]:	4753.78		4737.27		-16.51		4747.2	0.1		1917.6
# XGB[1]:	4019.99		4027.25		7.27
# XGB[2]:	4816.35		4802.39		-13.96
# XGB[5]:	3520.64		3573.10		52.46
#
# Fixed depth
# Linear depth
# dynamic depth
# [08:23:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [08:23:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [08:23:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 20 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3434.19		3488.38		54.19		3456.0	0.6		1474.1
# FGB[2]:	4164.23		4158.79		-5.44		4162.1	0.2		1769.9
# FGB[1]:	4690.08		4675.40		-14.68		4684.2	0.0		2267.3
# XGB[1]:	3978.01		3986.45		8.44
# XGB[2]:	4753.08		4737.88		-15.20
# XGB[5]:	3480.73		3536.51		55.77
#
# Fixed depth
# Linear depth
# dynamic depth
# [08:54:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [08:54:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [08:54:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 21 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3404.14		3461.24		57.10		3427.1	0.6		1605.8
# FGB[3]:	4085.35		4082.45		-2.91		4084.2	0.7		1794.1
# FGB[1]:	4631.54		4615.79		-15.75		4625.2	0.1		2010.8
# XGB[1]:	3936.50		3946.18		9.68
# XGB[2]:	4691.45		4677.51		-13.94
# XGB[5]:	3447.91		3508.33		60.42
#
# Fixed depth
# Linear depth
# dynamic depth
# [09:25:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [09:25:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:25:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 22 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3378.06		3438.06		60.00		3402.2	0.5		1315.1
# FGB[3]:	4022.62		4022.29		-0.33		4022.5	0.1		1559.8
# FGB[1]:	4574.41		4562.38		-12.03		4569.6	0.2		1659.1
# XGB[1]:	3901.58		3912.51		10.93
# XGB[2]:	4633.08		4618.05		-15.03
# XGB[5]:	3417.46		3481.56		64.10
#
# Fixed depth
# Linear depth
# dynamic depth
# [09:56:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [09:57:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:57:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 23 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3354.75		3417.98		63.23		3380.2	0.5		1392.0
# FGB[3]:	3964.67		3967.02		2.35		3965.6	0.8		1410.4
# FGB[1]:	4524.14		4510.77		-13.37		4518.8	0.1		1624.1
# XGB[1]:	3871.82		3884.94		13.12
# XGB[2]:	4576.36		4564.95		-11.41
# XGB[5]:	3390.10		3456.84		66.74
#
# Fixed depth
# Linear depth
# dynamic depth
# [10:28:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [10:28:35] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:28:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 24 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3333.68		3400.07		66.38		3360.4	0.6		1320.6
# FGB[3]:	3909.18		3914.65		5.46		3911.3	0.3		1474.2
# FGB[1]:	4475.12		4463.37		-11.75		4470.4	0.0		1983.0
# XGB[1]:	3842.51		3856.93		14.43
# XGB[2]:	4527.04		4514.16		-12.87
# XGB[5]:	3364.99		3434.52		69.54
#
# Fixed depth
# Linear depth
# dynamic depth
# [11:00:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [11:00:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:00:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 25 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3313.61		3383.28		69.67		3341.6	0.5		1620.6
# FGB[3]:	3866.32		3874.15		7.83		3869.4	0.1		1303.2
# FGB[1]:	4428.86		4416.74		-12.12		4424.0	0.1		1695.8
# XGB[1]:	3817.10		3832.75		15.65
# XGB[2]:	4478.78		4468.44		-10.35
# XGB[5]:	3342.25		3414.72		72.48
#
# Fixed depth
# Linear depth
# dynamic depth
# [11:31:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [11:31:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:31:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 26 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3295.61		3368.11		72.50		3324.8	0.7		1172.8
# FGB[3]:	3827.33		3838.16		10.83		3831.7	0.2		1084.4
# FGB[1]:	4383.70		4375.29		-8.41		4380.3	0.2		1444.4
# XGB[1]:	3795.81		3813.10		17.29
# XGB[2]:	4432.47		4421.40		-11.07
# XGB[5]:	3320.94		3397.54		76.60
#
# Fixed depth
# Linear depth
# dynamic depth
# [12:03:48] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [12:03:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:04:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 27 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3278.47		3353.84		75.36		3308.8	0.5		1330.3
# FGB[3]:	3793.76		3806.63		12.86		3798.9	0.4		1036.0
# FGB[1]:	4344.34		4335.41		-8.93		4340.8	0.1		1343.6
# XGB[1]:	3774.76		3793.13		18.37
# XGB[2]:	4389.53		4381.83		-7.70
# XGB[5]:	3301.73		3381.44		79.71
#
# Fixed depth
# Linear depth
# dynamic depth
# [12:35:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [12:35:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:36:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 28 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3264.79		3342.66		77.87		3296.1	0.6		1280.6
# FGB[3]:	3766.21		3780.40		14.19		3771.9	0.2		1009.4
# FGB[1]:	4306.54		4299.35		-7.19		4303.7	0.1		1661.3
# XGB[1]:	3756.50		3775.21		18.72
# XGB[2]:	4349.85		4341.84		-8.00
# XGB[5]:	3284.68		3367.66		82.98
#
# Fixed depth
# Linear depth
# dynamic depth
# [13:07:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [13:07:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:07:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 29 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3250.25		3330.53		80.28		3282.6	0.4		1355.4
# FGB[3]:	3744.39		3760.69		16.29		3750.9	0.3		1303.2
# FGB[1]:	4271.71		4263.95		-7.76		4268.6	0.1		1487.6
# XGB[1]:	3740.52		3760.45		19.93
# XGB[2]:	4310.55		4304.32		-6.23
# XGB[5]:	3269.31		3354.61		85.30
#
# Fixed depth
# Linear depth
# dynamic depth
# [13:39:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [13:39:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:39:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 30 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3237.69		3320.94		83.25		3271.2	0.7		1298.9
# FGB[3]:	3721.42		3739.22		17.80		3728.5	1.6		796.6
# FGB[1]:	4235.89		4231.38		-4.50		4234.1	0.2		1272.2
# XGB[1]:	3726.87		3748.27		21.39
# XGB[2]:	4274.75		4267.88		-6.87
# XGB[5]:	3255.48		3342.95		87.47
#
# Fixed depth
# Linear depth
# dynamic depth
# [14:15:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [14:15:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:15:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 31 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3224.28		3310.41		86.13		3259.0	1.0		1270.4
# FGB[4]:	3693.57		3712.98		19.41		3701.3	0.2		1099.3
# FGB[1]:	4202.25		4197.24		-5.01		4200.2	0.2		1319.9
# XGB[1]:	3713.57		3736.18		22.61
# XGB[2]:	4241.36		4237.39		-3.98
# XGB[5]:	3245.44		3334.29		88.85
#
# Fixed depth
# Linear depth
# dynamic depth
# [14:50:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [14:50:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:50:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 32 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3214.89		3302.66		87.77		3250.2	0.8		1190.4
# FGB[4]:	3667.98		3689.12		21.14		3676.4	0.7		1047.0
# FGB[1]:	4171.58		4168.39		-3.19		4170.3	0.2		1136.8
# XGB[1]:	3703.00		3726.62		23.62
# XGB[2]:	4209.74		4205.35		-4.39
# XGB[5]:	3231.34		3322.67		91.33
#
# Fixed depth
# Linear depth
# dynamic depth
# [15:26:11] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [15:26:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:26:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 33 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3203.12		3293.51		90.39		3239.5	0.4		1504.6
# FGB[4]:	3645.99		3668.31		22.32		3654.9	0.3		940.8
# FGB[1]:	4143.77		4140.71		-3.06		4142.5	0.1		1180.5
# XGB[1]:	3692.80		3717.41		24.61
# XGB[2]:	4179.81		4177.20		-2.61
# XGB[5]:	3221.81		3315.13		93.32
#
# Fixed depth
# Linear depth
# dynamic depth
# [16:01:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [16:01:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:01:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 34 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3193.62		3286.06		92.44		3230.9	1.9		1197.7
# FGB[4]:	3628.57		3652.30		23.73		3638.1	0.7		1238.8
# FGB[1]:	4116.42		4115.49		-0.92		4116.0	0.2		1466.7
# XGB[1]:	3682.73		3707.84		25.11
# XGB[2]:	4152.35		4149.18		-3.17
# XGB[5]:	3209.63		3304.95		95.31
#
# Fixed depth
# Linear depth
# dynamic depth
# [16:36:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [16:37:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:37:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 35 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3185.80		3280.07		94.26		3223.8	1.2		986.0
# FGB[4]:	3610.75		3635.41		24.66		3620.6	1.0		835.0
# FGB[1]:	4091.69		4090.29		-1.41		4091.1	0.2		1128.7
# XGB[1]:	3673.80		3699.87		26.07
# XGB[2]:	4126.38		4125.78		-0.61
# XGB[5]:	3201.90		3298.45		96.55
#
# Fixed depth
# Linear depth
# dynamic depth
# [17:12:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [17:12:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:12:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 36 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3176.48		3272.53		96.04		3215.2	0.5		1006.1
# FGB[4]:	3598.23		3624.27		26.04		3608.7	0.6		1096.0
# FGB[1]:	4067.83		4068.90		1.07		4068.3	0.2		1010.4
# XGB[1]:	3666.47		3693.06		26.60
# XGB[2]:	4101.52		4100.69		-0.83
# XGB[5]:	3189.81		3288.72		98.91
#
# Fixed depth
# Linear depth
# dynamic depth
# [17:48:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [17:48:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:48:51] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 37 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3169.80		3267.03		97.23		3209.0	0.9		924.4
# FGB[4]:	3584.17		3611.42		27.25		3595.1	0.6		759.0
# FGB[1]:	4044.99		4046.02		1.03		4045.4	0.1		1186.8
# XGB[1]:	3659.72		3686.89		27.17
# XGB[2]:	4078.57		4079.54		0.98
# XGB[5]:	3178.94		3279.61		100.67
#
# Fixed depth
# Linear depth
# dynamic depth
# [18:24:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [18:24:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 38 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3162.90		3261.65		98.75		3202.7	1.0		1134.7
# FGB[4]:	3570.12		3598.31		28.18		3581.4	0.6		756.1
# FGB[1]:	4024.64		4027.28		2.64		4025.7	0.1		1021.8
# XGB[1]:	3652.79		3680.15		27.36
# XGB[2]:	4056.70		4056.96		0.26
# XGB[5]:	3171.92		3274.02		102.10
#
# Fixed depth
# Linear depth
# dynamic depth
# [19:03:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [19:04:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:04:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 39 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3156.48		3257.34		100.86		3197.2	0.5		1257.1
# FGB[4]:	3558.91		3588.54		29.63		3570.8	1.1		1170.6
# FGB[2]:	3983.52		3988.03		4.51		3985.3	0.1		1238.4
# XGB[1]:	3646.20		3674.29		28.09
# XGB[2]:	4036.01		4037.74		1.73
# XGB[5]:	3162.58		3267.93		105.35
#
# Fixed depth
# Linear depth
# dynamic depth
# [19:44:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [19:44:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:44:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 40 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3148.04		3250.64		102.61		3189.4	0.6		1098.9
# FGB[4]:	3546.87		3577.59		30.72		3559.2	0.7		727.3
# FGB[2]:	3946.33		3952.83		6.50		3948.9	2.0		1385.8
# XGB[1]:	3640.87		3669.70		28.82
# XGB[2]:	4017.46		4019.04		1.58
# XGB[5]:	3155.71		3263.19		107.48
# Fixed depth
# Linear depth
# dynamic depth
# [20:27:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [20:27:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:27:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 41 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3141.53		3246.16		104.63		3183.8	1.4		1214.0
# FGB[5]:	3529.24		3562.18		32.93		3542.4	0.2		1247.0
# FGB[2]:	3913.06		3920.27		7.21		3915.9	5.2		1197.8
# XGB[1]:	3634.54		3663.60		29.07
# XGB[2]:	3999.59		4003.03		3.43
# XGB[5]:	3150.51		3259.83		109.32
#
# Fixed depth
# Linear depth
# dynamic depth
# [21:09:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [21:09:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:09:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 42 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3135.57		3241.87		106.30		3178.5	1.5		1221.3
# FGB[5]:	3517.30		3552.97		35.67		3531.6	0.8		1582.7
# FGB[2]:	3886.73		3895.59		8.86		3890.2	0.4		1194.1
# XGB[1]:	3629.48		3659.06		29.58
# XGB[2]:	3982.65		3985.68		3.03
# XGB[5]:	3144.39		3255.26		110.87
#
# Fixed depth
# Linear depth
# dynamic depth
# [21:53:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [21:53:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:53:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 43 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3127.47		3235.77		108.29		3171.2	0.8		1330.2
# FGB[5]:	3502.66		3541.05		38.40		3518.0	1.6		1679.8
# FGB[2]:	3859.59		3869.46		9.87		3863.4	1.3		876.0
# XGB[1]:	3624.79		3654.66		29.87
# XGB[2]:	3966.58		3971.36		4.77
# XGB[5]:	3138.44		3251.28		112.84
#
# Fixed depth
# Linear depth
# dynamic depth
# [22:36:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [22:37:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:37:12] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 44 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3120.70		3231.02		110.32		3165.3	0.7		1239.6
# FGB[5]:	3484.22		3526.67		42.46		3501.2	0.5		1339.7
# FGB[2]:	3834.90		3846.03		11.13		3839.3	0.3		1226.4
# XGB[1]:	3620.77		3651.05		30.29
# XGB[2]:	3951.80		3956.48		4.68
# XGB[5]:	3131.12		3246.22		115.09
#
# Fixed depth
# Linear depth
# dynamic depth
# [23:19:38] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [23:19:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [23:19:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 45 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3112.09		3225.69		113.61		3158.0	0.9		919.4
# FGB[5]:	3473.78		3518.32		44.54		3491.6	1.1		1306.8
# FGB[2]:	3815.43		3828.17		12.74		3820.5	0.1		1075.8
# XGB[1]:	3615.57		3646.05		30.48
# XGB[2]:	3937.99		3944.31		6.31
# XGB[5]:	3125.01		3242.68		117.67
#
# Fixed depth
# Linear depth
# dynamic depth
# [00:06:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [00:06:25] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:06:30] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 46 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3105.64		3221.13		115.49		3152.3	1.5		1363.7
# FGB[5]:	3458.67		3506.61		47.94		3477.9	0.6		2007.3
# FGB[3]:	3787.67		3801.70		14.03		3793.2	0.2		979.6
# XGB[1]:	3611.69		3642.79		31.10
# XGB[2]:	3924.93		3931.17		6.24
# XGB[5]:	3118.11		3238.26		120.15
#
# Fixed depth
# Linear depth
# dynamic depth
# [00:55:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [00:55:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:55:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 47 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3097.37		3215.29		117.93		3145.1	0.6		1385.7
# FGB[5]:	3443.80		3494.62		50.82		3464.2	1.5		978.2
# FGB[3]:	3763.34		3778.40		15.06		3769.3	0.3		825.1
# XGB[1]:	3607.60		3639.20		31.60
# XGB[2]:	3912.71		3920.34		7.63
# XGB[5]:	3111.96		3235.12		123.17
#
# Fixed depth
# Linear depth
# dynamic depth
# [01:47:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [01:47:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:47:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 48 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3091.95		3211.31		119.37		3140.2	0.9		915.3
# FGB[5]:	3432.68		3485.82		53.14		3454.0	0.7		1496.6
# FGB[3]:	3744.02		3760.52		16.50		3750.6	0.4		948.1
# XGB[1]:	3603.33		3635.46		32.13
# XGB[2]:	3901.27		3908.61		7.34
# XGB[5]:	3103.87		3230.24		126.37
#
# Fixed depth
# Linear depth
# dynamic depth
# [02:44:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [02:44:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:44:29] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 49 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3085.34		3206.74		121.40		3134.5	1.2		1097.8
# FGB[5]:	3418.82		3475.16		56.35		3441.4	0.8		1462.9
# FGB[4]:	3715.29		3733.68		18.39		3722.7	0.4		1141.1
# XGB[1]:	3599.81		3632.37		32.55
# XGB[2]:	3890.55		3899.31		8.76
# XGB[5]:	3097.42		3225.96		128.54
#
# Fixed depth
# Linear depth
# dynamic depth
# [03:39:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [03:40:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:40:07] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 50 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3079.32		3202.32		123.00		3129.1	0.9		1131.8
# FGB[5]:	3408.92		3467.68		58.76		3432.5	0.7		1460.0
# FGB[4]:	3693.88		3714.68		20.80		3702.2	0.7		1484.3
# XGB[1]:	3596.12		3628.97		32.85
# XGB[2]:	3880.39		3889.27		8.88
# XGB[5]:	3089.76		3221.71		131.95
#
# Fixed depth
# Linear depth
# dynamic depth
# [04:33:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [04:33:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:33:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 51 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3073.49		3198.71		125.22		3124.2	0.9		1037.3
# FGB[5]:	3398.66		3459.55		60.89		3423.1	1.1		1477.7
# FGB[4]:	3670.82		3693.22		22.40		3679.8	1.4		981.4
# XGB[1]:	3592.76		3625.72		32.96
# XGB[2]:	3870.61		3881.03		10.42
# XGB[5]:	3084.46		3218.98		134.51
#
# Fixed depth
# Linear depth
# dynamic depth
# [05:27:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [05:27:40] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:27:45] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 52 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3066.81		3194.71		127.89		3118.6	0.5		1469.3
# FGB[5]:	3390.82		3453.60		62.78		3416.1	0.9		1297.4
# FGB[4]:	3649.50		3673.09		23.59		3659.0	0.3		968.7
# XGB[1]:	3588.51		3622.19		33.68
# XGB[2]:	3861.77		3871.82		10.05
# XGB[5]:	3076.78		3213.97		137.19
#
# Fixed depth
# Linear depth
# dynamic depth
# [06:22:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [06:23:04] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:23:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 53 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3059.64		3189.76		130.11		3112.3	1.0		1464.2
# FGB[5]:	3382.42		3447.71		65.29		3408.7	0.9		1434.5
# FGB[4]:	3632.41		3657.79		25.38		3642.6	0.6		972.0
# XGB[1]:	3584.21		3617.63		33.42
# XGB[2]:	3853.62		3864.97		11.35
# XGB[5]:	3072.30		3211.74		139.44
#
# Fixed depth
# Linear depth
# dynamic depth
# [07:20:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [07:21:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [07:21:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 54 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3053.80		3186.15		132.34		3107.4	1.0		1658.9
# FGB[5]:	3374.36		3442.46		68.09		3401.8	0.5		1910.9
# FGB[5]:	3614.21		3642.24		28.03		3625.4	0.4		1362.5
# XGB[1]:	3581.31		3614.70		33.39
# XGB[2]:	3845.68		3857.05		11.37
# XGB[5]:	3065.75		3208.01		142.26
#
# Fixed depth
# Linear depth
# dynamic depth
# [08:18:23] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [08:18:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [08:18:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 55 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3047.26		3182.43		135.17		3102.0	1.5		1278.9
# FGB[5]:	3363.68		3433.52		69.84		3391.8	1.1		1050.7
# FGB[5]:	3591.71		3622.97		31.26		3604.2	0.6		1535.9
# XGB[1]:	3578.56		3612.60		34.04
# XGB[2]:	3838.16		3850.74		12.57
# XGB[5]:	3060.19		3204.52		144.33
#
# Fixed depth
# Linear depth
# dynamic depth
# [09:11:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [09:12:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:12:20] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 56 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3041.89		3179.10		137.21		3097.5	1.4		1275.0
# FGB[5]:	3353.96		3426.60		72.64		3383.2	0.8		1602.9
# FGB[5]:	3574.46		3608.76		34.30		3588.2	1.3		1414.6
# XGB[1]:	3575.72		3610.23		34.51
# XGB[2]:	3831.25		3843.45		12.19
# XGB[5]:	3052.69		3200.08		147.39
#
# Fixed depth
# Linear depth
# dynamic depth
# [10:04:19] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [10:04:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:04:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 57 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3035.57		3174.38		138.81		3091.8	1.0		1253.3
# FGB[5]:	3347.05		3421.18		74.13		3376.9	0.8		1597.8
# FGB[5]:	3555.58		3592.68		37.10		3570.5	0.8		1446.4
# XGB[1]:	3573.19		3607.85		34.66
# XGB[2]:	3824.79		3838.19		13.41
# XGB[5]:	3046.46		3196.59		150.13
#
# Fixed depth
# Linear depth
# dynamic depth
# [10:58:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [10:58:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:59:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 58 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3030.95		3171.89		140.94		3088.1	1.3		1311.5
# FGB[5]:	3337.11		3413.77		76.65		3368.0	1.3		1367.5
# FGB[5]:	3537.14		3577.07		39.92		3553.2	0.5		1369.9
# XGB[1]:	3570.53		3605.49		34.96
# XGB[2]:	3818.67		3832.10		13.43
# XGB[5]:	3041.28		3193.98		152.69
#
# Fixed depth
# Linear depth
# dynamic depth
# [11:54:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [11:55:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [11:55:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 59 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3021.32		3163.91		142.59		3079.1	0.5		959.5
# FGB[5]:	3328.24		3407.18		78.94		3360.0	0.6		1429.5
# FGB[5]:	3522.44		3564.47		42.03		3539.3	0.4		1619.0
# XGB[1]:	3567.33		3602.84		35.51
# XGB[2]:	3812.96		3827.34		14.37
# XGB[5]:	3036.43		3191.26		154.83
# Fixed depth
# Linear depth
# dynamic depth
# [12:53:56] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [12:54:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [12:54:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 60 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3016.62		3161.25		144.63		3075.3	0.5		1079.9
# FGB[5]:	3322.06		3403.91		81.85		3355.0	0.6		1207.6
# FGB[5]:	3508.13		3553.27		45.14		3526.2	1.2		856.6
# XGB[1]:	3565.51		3600.89		35.38
# XGB[2]:	3807.42		3821.75		14.33
# XGB[5]:	3030.13		3187.95		157.83
#
# Fixed depth
# Linear depth
# dynamic depth
# [13:53:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [13:54:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [13:54:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 61 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3011.46		3158.43		146.98		3071.1	2.1		1486.1
# FGB[5]:	3313.19		3397.14		83.95		3347.0	0.7		920.3
# FGB[5]:	3498.08		3545.05		46.96		3516.9	0.5		1332.5
# XGB[1]:	3563.62		3599.41		35.79
# XGB[2]:	3802.45		3817.73		15.28
# XGB[5]:	3023.78		3184.20		160.42
#
# Fixed depth
# Linear depth
# dynamic depth
# [14:55:50] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [14:56:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [14:56:16] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 62 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3007.16		3155.85		148.69		3067.5	1.2		972.7
# FGB[5]:	3306.63		3392.71		86.09		3341.3	0.8		1245.3
# FGB[5]:	3482.52		3531.86		49.35		3502.3	0.8		1052.4
# XGB[1]:	3561.13		3597.14		36.00
# XGB[2]:	3797.56		3812.58		15.02
# XGB[5]:	3020.56		3182.32		161.76
#
# Fixed depth
# Linear depth
# dynamic depth
# [15:56:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [15:56:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:56:34] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 63 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	3001.45		3152.19		150.74		3062.6	0.7		1240.6
# FGB[5]:	3298.06		3385.99		87.93		3333.5	0.9		1351.0
# FGB[5]:	3465.78		3518.16		52.39		3486.8	0.5		1351.9
# XGB[1]:	3559.15		3595.19		36.04
# XGB[2]:	3793.14		3808.14		15.00
# XGB[5]:	3013.93		3178.26		164.33
#
# Fixed depth
# Linear depth
# dynamic depth
# [16:55:42] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [16:56:03] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [16:56:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 64 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2996.60		3149.43		152.83		3058.6	1.1		1329.9
# FGB[5]:	3292.00		3382.26		90.26		3328.4	1.5		1365.4
# FGB[5]:	3454.76		3509.84		55.08		3476.9	1.0		1152.2
# XGB[1]:	3556.99		3593.22		36.23
# XGB[2]:	3788.74		3804.56		15.82
# XGB[5]:	3008.90		3175.27		166.37
#
# Fixed depth
# Linear depth
# dynamic depth
# [17:56:32] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [17:56:52] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [17:56:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 65 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2992.25		3146.87		154.62		3055.0	2.7		1065.0
# FGB[5]:	3286.16		3378.14		91.98		3323.3	0.6		1455.9
# FGB[5]:	3441.27		3499.08		57.81		3464.5	0.7		874.5
# XGB[1]:	3554.46		3591.26		36.80
# XGB[2]:	3784.77		3800.83		16.06
# XGB[5]:	3002.67		3172.15		169.48
#
# Fixed depth
# Linear depth
# dynamic depth
# [18:57:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [18:57:27] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:57:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 66 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2984.86		3142.19		157.33		3048.8	1.0		1104.6
# FGB[5]:	3275.85		3369.93		94.08		3313.8	0.9		1283.5
# FGB[5]:	3429.89		3490.33		60.44		3454.2	0.5		1839.1
# XGB[1]:	3552.47		3589.15		36.68
# XGB[2]:	3780.88		3797.59		16.71
# XGB[5]:	2998.50		3170.37		171.87
#
# Fixed depth
# Linear depth
# dynamic depth
# ...
# [17:26:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 90 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2857.60		3069.62		212.01		2944.2	0.7		1292.5
# FGB[5]:	3114.20		3263.36		149.16		3174.7	1.3		1038.3
# FGB[5]:	3236.59		3350.87		114.28		3282.8	1.8		1546.6
# XGB[1]:	3512.96		3554.06		41.10
# XGB[2]:	3718.74		3740.45		21.72
# XGB[5]:	2883.43		3105.78		222.35
#
# Fixed depth
# Linear depth
# dynamic depth
# [18:24:05] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [18:24:33] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [18:24:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 91 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2852.13		3066.09		213.96		2939.6	1.3		730.6
# FGB[5]:	3108.52		3259.45		150.93		3169.8	1.3		1224.7
# FGB[5]:	3229.34		3345.93		116.59		3276.5	0.7		786.4
# XGB[1]:	3511.88		3553.01		41.14
# XGB[2]:	3716.89		3739.15		22.26
# XGB[5]:	2879.06		3102.95		223.89
#
# Fixed depth
# Linear depth
# dynamic depth
# [19:24:13] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [19:24:41] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [19:24:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 92 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2847.76		3063.70		215.94		2936.0	0.7		1067.6
# FGB[5]:	3101.65		3255.40		153.75		3164.0	1.8		1317.0
# FGB[5]:	3223.01		3341.22		118.21		3270.8	0.5		1423.2
# XGB[1]:	3510.40		3551.91		41.51
# XGB[2]:	3715.07		3737.22		22.15
# XGB[5]:	2872.37		3098.18		225.81
#
# Fixed depth
# Linear depth
# dynamic depth
# [20:24:55] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [20:25:24] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [20:25:32] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 93 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2842.88		3060.80		217.92		2932.0	0.9		1086.9
# FGB[5]:	3095.93		3251.64		155.71		3159.1	1.4		1332.6
# FGB[5]:	3213.71		3333.35		119.64		3262.1	0.7		1431.1
# XGB[1]:	3509.42		3551.02		41.60
# XGB[2]:	3713.36		3735.81		22.45
# XGB[5]:	2864.95		3093.12		228.17
#
# Fixed depth
# Linear depth
# dynamic depth
# [21:24:43] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [21:25:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [21:25:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 94 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2838.27		3059.03		220.77		2928.6	0.9		1457.9
# FGB[5]:	3088.92		3247.93		159.01		3153.5	3.0		1698.1
# FGB[5]:	3206.75		3328.81		122.06		3256.1	1.7		1349.8
# XGB[1]:	3508.35		3549.97		41.62
# XGB[2]:	3711.65		3734.38		22.73
# XGB[5]:	2859.87		3090.97		231.10
#
# Fixed depth
# Linear depth
# dynamic depth
# [22:23:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [22:23:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [22:23:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 95 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2832.22		3054.74		222.52		2923.3	1.7		1034.9
# FGB[5]:	3078.90		3240.89		161.99		3144.7	0.9		948.8
# FGB[5]:	3197.14		3321.49		124.35		3247.5	0.6		1290.5
# XGB[1]:	3506.92		3549.02		42.10
# XGB[2]:	3709.98		3732.99		23.01
# XGB[5]:	2856.35		3089.39		233.05
#
# Fixed depth
# Linear depth
# dynamic depth
# [23:25:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [23:25:44] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [23:25:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 96 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2826.58		3052.22		225.65		2918.9	0.9		940.6
# FGB[5]:	3072.75		3237.97		165.22		3139.9	0.7		1224.8
# FGB[5]:	3189.95		3317.17		127.22		3241.4	0.9		1142.1
# XGB[1]:	3505.87		3547.99		42.11
# XGB[2]:	3708.30		3731.27		22.96
# XGB[5]:	2852.55		3087.78		235.23
#
# Fixed depth
# Linear depth
# dynamic depth
# [00:30:58] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [00:31:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [00:31:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 97 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2821.60		3049.58		227.98		2914.9	1.1		1060.7
# FGB[5]:	3067.49		3234.76		167.27		3135.5	1.2		1044.5
# FGB[5]:	3182.86		3312.68		129.82		3235.4	0.8		1234.4
# XGB[1]:	3504.57		3546.84		42.26
# XGB[2]:	3706.72		3729.38		22.65
# XGB[5]:	2850.26		3086.45		236.19
#
# Fixed depth
# Linear depth
# dynamic depth
# [01:30:37] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [01:31:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [01:31:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 98 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2817.18		3047.34		230.16		2911.4	1.0		1322.1
# FGB[5]:	3062.60		3232.55		169.95		3131.7	1.4		1479.3
# FGB[5]:	3178.13		3310.82		132.69		3231.9	0.7		1587.2
# XGB[1]:	3502.81		3545.47		42.66
# XGB[2]:	3705.17		3727.73		22.56
# XGB[5]:	2846.83		3084.67		237.84
#
# Fixed depth
# Linear depth
# dynamic depth
# [02:30:08] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [02:30:39] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [02:30:47] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 99 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2813.04		3044.77		231.73		2907.9	1.2		861.0
# FGB[5]:	3057.19		3230.41		173.22		3127.6	1.7		1235.2
# FGB[5]:	3172.83		3307.70		134.87		3227.5	1.3		1512.2
# XGB[1]:	3501.23		3544.24		43.00
# XGB[2]:	3703.63		3726.65		23.02
# XGB[5]:	2842.92		3082.84		239.92
#
# Fixed depth
# Linear depth
# dynamic depth
# [03:29:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [03:30:06] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [03:30:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 100 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2808.58		3042.57		233.99		2904.4	0.9		1252.3
# FGB[5]:	3049.49		3225.04		175.55		3120.9	0.7		1269.6
# FGB[5]:	3166.34		3303.13		136.79		3221.7	1.0		1029.8
# XGB[1]:	3500.00		3543.49		43.49
# XGB[2]:	3702.11		3725.33		23.22
# XGB[5]:	2838.26		3079.69		241.43
#
# Fixed depth
# Linear depth
# dynamic depth
# [04:31:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [04:32:17] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [04:32:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 101 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2804.22		3040.34		236.12		2901.0	1.6		1023.8
# FGB[5]:	3043.91		3221.28		177.38		3116.1	1.1		1359.7
# FGB[5]:	3159.30		3298.23		138.93		3215.6	0.7		1294.2
# XGB[1]:	3498.63		3542.21		43.58
# XGB[2]:	3700.71		3723.97		23.25
# XGB[5]:	2835.93		3078.22		242.29
#
# Fixed depth
# Linear depth
# dynamic depth
# [05:33:15] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [05:33:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [05:33:57] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 102 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2798.70		3036.83		238.13		2896.3	1.3		985.8
# FGB[5]:	3035.13		3215.70		180.58		3108.6	0.6		1325.6
# FGB[5]:	3154.33		3295.85		141.52		3211.7	1.5		1301.1
# XGB[1]:	3497.64		3541.27		43.63
# XGB[2]:	3699.29		3722.86		23.57
# XGB[5]:	2832.90		3076.51		243.61
#
# Fixed depth
# Linear depth
# dynamic depth
# [06:33:28] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [06:34:00] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [06:34:09] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 103 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2795.20		3035.22		240.02		2893.6	0.9		1033.5
# FGB[5]:	3029.31		3211.87		182.56		3103.6	0.8		1464.8
# FGB[5]:	3148.80		3291.91		143.12		3206.8	0.5		1315.4
# XGB[1]:	3496.46		3540.40		43.93
# XGB[2]:	3697.91		3721.75		23.84
# XGB[5]:	2827.82		3073.66		245.84
#
# Fixed depth
# Linear depth
# dynamic depth
# [07:32:14] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [07:32:46] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [07:32:54] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 104 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2791.92		3033.36		241.43		2890.9	1.2		940.9
# FGB[5]:	3023.47		3208.66		185.19		3098.9	0.8		1121.5
# FGB[5]:	3142.73		3288.34		145.61		3201.8	0.7		1283.6
# XGB[1]:	3495.37		3539.43		44.06
# XGB[2]:	3696.51		3720.82		24.31
# XGB[5]:	2823.74		3071.86		248.13
#
# Fixed depth
# Linear depth
# dynamic depth
# [08:28:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [08:28:53] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [08:29:02] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 105 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2785.36		3028.89		243.53		2885.2	0.7		1019.2
# FGB[5]:	3017.66		3204.84		187.17		3093.9	0.6		1285.0
# FGB[5]:	3136.46		3285.31		148.85		3196.8	0.8		1418.7
# XGB[1]:	3494.63		3538.66		44.03
# XGB[2]:	3695.18		3719.24		24.06
# XGB[5]:	2818.17		3068.62		250.45
#
# Fixed depth
# Linear depth
# dynamic depth
# [09:25:26] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [09:26:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [09:26:10] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
#
# -----------------------------------------------
# ittr 106 	Train		Test		Diff		RVar	SVar	TVar
# FGB[5]:	2781.74		3027.84		246.10		2882.7	1.5		1180.7
# FGB[5]:	3012.95		3202.12		189.17		3090.0	1.6		1280.5
# FGB[5]:	3131.78		3282.23		150.46		3192.8	3.5		1525.1
# XGB[1]:	3493.62		3537.78		44.16
# XGB[2]:	3693.87		3717.80		23.92
# XGB[5]:	2814.90		3066.56		251.66
#
# Fixed depth
# Linear depth
# dynamic depth
# [10:20:49] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# [10:21:22] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10:21:31] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGB
# ------------------------------------------------------------------------
# MemoryError                            Traceback (most recent call last)
# <ipython-input-22-912815074a7d> in <module>
#      95         i+=1
#      96
# ---> 97         save()
#      98
#      99         log('\r\n-----------------------------------------------\r\n'+
#
# <ipython-input-7-8ec4ae5821cf> in save()
#      31 def save():
#      32     with open('data2.dat','wb') as f:
# ---> 33         pickle.dump((i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse),f)
#      34 def load():
#      35     global i,mdl_1,mdl_2,mdl_3,RMSETest,RMSETrain,last_depth,last_rmse
#
# MemoryError:

# %%
from numpy import std
std(mdl_1.trees[1][1].get_leaf_values())
# Out:
# 3583.6941556549373

# %%
load1()
loaddf()

# %%
def sumcnt(Node):
    if Node.isLeaf:
        return Node.cnt
    return sumcnt(Node.Left)+sumcnt(Node.Right)
sumcnt(node)
# Out:
# 36000

# %%
node = mdl_1.trees[57][1]
node.predict(X_test)
node.draw_tree()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(500, 500))
removeXY(mdl.trees[58][2])
mdl.trees[85][0].draw_tree(ax=ax)
plt.show()

# %%
import xgboost as xgb
from xgboost import plot_tree
from sklearn.metrics import mean_squared_error

xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                max_depth = 5,  n_estimators = 8)
xg_reg.fit(X_train,y_train)
preds = xg_reg.predict(X_test)
print('RMSE: %f'%np.sqrt(mean_squared_error(y_test, preds)))
for a,b in  zip(y_test[:10],preds[:10]):
    print('%0.2f\t%0.2f\t%0.2f'%(a,b,abs(a-b)))
# Out:
# [09:07:36] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE: 40800.016106
# 98135.69	52899.11	45236.58
# 103259.84	53311.32	49948.52
# 96434.01	52821.76	43612.25
# 80954.96	50414.98	30539.98
# 103742.74	53180.94	50561.80
# 97814.02	53180.94	44633.08
# 101013.30	55209.25	45804.05
# 90743.07	53180.94	37562.13
# 96397.29	54454.34	41942.95
# 93122.03	52760.19	40361.84

# %%
        xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                        max_depth = 1,  n_estimators = i)
        xg_reg.fit(X_train,y_train_xgb)    
        preds = xg_reg.predict(X_train)
        print(np.sqrt(mean_squared_error(y_train, [p+m for p in preds])))
        preds = xg_reg.predict(X_test)
        print(np.sqrt(mean_squared_error(y_test, [p+m for p in preds])))
        
                
        xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                        max_depth = 2,  n_estimators = i)
        xg_reg.fit(X_train,y_train_xgb)    
        preds = xg_reg.predict(X_train)
        print(np.sqrt(mean_squared_error(y_train, [p+m for p in preds])))
        preds = xg_reg.predict(X_test)
        print(np.sqrt(mean_squared_error(y_test, [p+m for p in preds])))
# Out:
# [03:49:59] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 5515.560315843102
# 5497.0595696182345
# [03:50:01] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# 4666.288729677609
# 4655.809304430131

# %%
mdl_1.trees[58][1].print_tree()
# Out:
# '\t8239 [label="f0>=0.937574"]\n\t8239 -> 8240 [label="yes" color="#0000FF"]\n\t 8239 -> 8241 [label=no color="#FF0000"]\n\t8240 [label="f1>=566.000000"]\n\t8240 -> 8242 [label="yes" color="#0000FF"]\n\t 8240 -> 8243 [label=no color="#FF0000"]\n\t8242 [label="f0>=261.687736"]\n\t8242 -> 8244 [label="yes" color="#0000FF"]\n\t 8242 -> 8245 [label=no color="#FF0000"]\n\t8244 [label="f0>=295.245304"]\n\t8244 -> 8246 [label="yes" color="#0000FF"]\n\t 8244 -> 8247 [label=no color="#FF0000"]\n\t8246 [label="f0>=300.930229"]\n\t8246 -> 8248 [label="yes" color="#0000FF"]\n\t 8246 -> 8249 [label=no color="#FF0000"]\n\t8248 [label="leaf=-9.042450\nleafNo=1"]\n\t8249 [label="leaf=3313.563438\nleafNo=2"]\n\t8247 [label="f2>=12.680816"]\n\t8247 -> 8250 [label="yes" color="#0000FF"]\n\t 8247 -> 8251 [label=no color="#FF0000"]\n\t8250 [label="leaf=-967.480983\nleafNo=3"]\n\t8251 [label="leaf=-7502.263990\nleafNo=4"]\n\t8245 [label="f0>=195.196900"]\n\t8245 -> 8252 [label="yes" color="#0000FF"]\n\t 8245 -> 8253 [label=no color="#FF0000"]\n\t8252 [label="f0>=200.469942"]\n\t8252 -> 8254 [label="yes" color="#0000FF"]\n\t 8252 -> 8255 [label=no color="#FF0000"]\n\t8254 [label="leaf=873.938784\nleafNo=5"]\n\t8255 [label="leaf=4777.270430\nleafNo=6"]\n\t8253 [label="f0>=185.983040"]\n\t8253 -> 8256 [label="yes" color="#0000FF"]\n\t 8253 -> 8257 [label=no color="#FF0000"]\n\t8256 [label="leaf=-2562.780162\nleafNo=7"]\n\t8257 [label="leaf=179.643239\nleafNo=8"]\n\t8243 [label="f1>=562.534704"]\n\t8243 -> 8258 [label="yes" color="#0000FF"]\n\t 8243 -> 8259 [label=no color="#FF0000"]\n\t8258 [label="f0>=477.253380"]\n\t8258 -> 8260 [label="yes" color="#0000FF"]\n\t 8258 -> 8261 [label=no color="#FF0000"]\n\t8260 [label="f1>=565.619300"]\n\t8260 -> 8262 [label="yes" color="#0000FF"]\n\t 8260 -> 8263 [label=no color="#FF0000"]\n\t8262 [label="leaf=1618.070658\nleafNo=9"]\n\t8263 [label="leaf=-521.731598\nleafNo=10"]\n\t8261 [label="f1>=563.983472"]\n\t8261 -> 8264 [label="yes" color="#0000FF"]\n\t 8261 -> 8265 [label=no color="#FF0000"]\n\t8264 [label="leaf=-1958.975142\nleafNo=11"]\n\t8265 [label="leaf=635.281219\nleafNo=12"]\n\t8259 [label="f2>=528.664980"]\n\t8259 -> 8266 [label="yes" color="#0000FF"]\n\t 8259 -> 8267 [label=no color="#FF0000"]\n\t8266 [label="f0>=478.088340"]\n\t8266 -> 8268 [label="yes" color="#0000FF"]\n\t 8266 -> 8269 [label=no color="#FF0000"]\n\t8268 [label="leaf=168.615430\nleafNo=13"]\n\t8269 [label="leaf=-216.767288\nleafNo=14"]\n\t8267 [label="f2>=518.465952"]\n\t8267 -> 8270 [label="yes" color="#0000FF"]\n\t 8267 -> 8271 [label=no color="#FF0000"]\n\t8270 [label="leaf=754.682656\nleafNo=15"]\n\t8271 [label="leaf=0.647138\nleafNo=16"]\n\t8241 [label="f0>=0.882300"]\n\t8241 -> 8272 [label="yes" color="#0000FF"]\n\t 8241 -> 8273 [label=no color="#FF0000"]\n\t8272 [label="f1>=118.781000"]\n\t8272 -> 8274 [label="yes" color="#0000FF"]\n\t 8272 -> 8275 [label=no color="#FF0000"]\n\t8274 [label="f0>=0.921500"]\n\t8274 -> 8276 [label="yes" color="#0000FF"]\n\t 8274 -> 8277 [label=no color="#FF0000"]\n\t8276 [label="leaf=2074.048631\nleafNo=17"]\n\t8277 [label="f0>=0.915300"]\n\t8277 -> 8278 [label="yes" color="#0000FF"]\n\t 8277 -> 8279 [label=no color="#FF0000"]\n\t8278 [label="leaf=1184.657930\nleafNo=18"]\n\t8279 [label="leaf=1665.625308\nleafNo=19"]\n\t8275 [label="f2>=214.367900"]\n\t8275 -> 8280 [label="yes" color="#0000FF"]\n\t 8275 -> 8281 [label=no color="#FF0000"]\n\t8280 [label="leaf=3543.698285\nleafNo=20"]\n\t8281 [label="f2>=186.546300"]\n\t8281 -> 8282 [label="yes" color="#0000FF"]\n\t 8281 -> 8283 [label=no color="#FF0000"]\n\t8282 [label="leaf=2434.110748\nleafNo=21"]\n\t8283 [label="leaf=2410.361763\nleafNo=22"]\n\t8273 [label="f2>=415.524200"]\n\t8273 -> 8284 [label="yes" color="#0000FF"]\n\t 8273 -> 8285 [label=no color="#FF0000"]\n\t8284 [label="f2>=525.961800"]\n\t8284 -> 8286 [label="yes" color="#0000FF"]\n\t 8284 -> 8287 [label=no color="#FF0000"]\n\t8286 [label="f1>=211.893000"]\n\t8286 -> 8288 [label="yes" ...

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
xg_reg = xgb.XGBRegressor( learning_rate = 0.1,
                max_depth = 5,  n_estimators = 100
                         )
xg_reg.fit(X_train,y_train)
preds = xg_reg.predict(X_test)
print('RMSE: %f'%np.sqrt(mean_squared_error(y_test, preds)))
for a,b in  zip(y_test[:10],preds[:10]):
    print('%0.2f\t%0.2f\t%0.2f'%(a,b,abs(a-b)))
# Out:
# [12:34:21] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# RMSE: 3238.733679
# 95716.83	96374.12	657.30
# 93197.34	90694.52	2502.82
# 93012.06	89242.32	3769.74
# 96252.08	95166.41	1085.68
# 100017.88	100426.52	408.64
# 89233.71	96014.59	6780.88
# 88295.06	91161.50	2866.44
# 97701.73	97152.05	549.68
# 102094.01	99968.95	2125.05
# 86614.54	84039.80	2574.74

# %%
import random
X = [[random.randint(1,10)] for i in range(20)]
Y = random.sample(range(1,100),20)
X=[[14],[10],[2],[62],[54],[93],[51],[61],[85],[49]]
Y=[34,22,96,72,79,25,83,48,54,5]
print(X)
print(Y)
mdl = FractBoosting(1)
mdl.fit(X,Y,1,3)
# Out:
# [[14], [10], [2], [62], [54], [93], [51], [61], [85], [49]]
# [34, 22, 96, 72, 79, 25, 83, 48, 54, 5]
# itteration 1, begining, mean loss: 28.648909
# splitting at 2.000000: cost->820.760000
# splitting at 10.000000: cost->603.688889
# splitting at 14.000000: cost->807.800000
# splitting at 49.000000: cost->820.209524
# splitting at 51.000000: cost->715.758333
# splitting at 54.000000: cost->806.320000
# splitting at 61.000000: cost->817.958333
# splitting at 62.000000: cost->819.838095
# splitting at 85.000000: cost->782.937500
# splitting at 93.000000: cost->740.955556
# itteration 1, middle, mean loss: 24.570081
# itteration 1, end, mean loss: 24.570081
# itteration 2, begining, mean loss: 24.570081
# splitting at 2.000000: cost->603.688889
# splitting at 10.000000: cost->603.688889
# splitting at 14.000000: cost->564.972840
# splitting at 49.000000: cost->535.728865
# splitting at 51.000000: cost->339.239815
# splitting at 54.000000: cost->527.805432
# splitting at 61.000000: cost->598.231584
# splitting at 62.000000: cost->598.604233
# splitting at 85.000000: cost->590.039969
# splitting at 93.000000: cost->550.452949
# itteration 2, middle, mean loss: 18.418464
# itteration 2, end, mean loss: 17.104746

# %%
def removeXY(node):
    if node == None:
        return
    node.X = node.Y = ''
    removeXY(node.Left)
    removeXY(node.Right)
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(500, 500))
removeXY(mdl.trees[85][0])
mdl.trees[85][0].draw_tree(ax=ax)
plt.show()

# %%
import xgboost as xgb
from xgboost import plot_tree
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
#print(os.environ["PATH"])
xg_reg = xgb.XGBRegressor( learning_rate = .1,
                max_depth = 5,  n_estimators = 80,)
xg_reg.fit(X_train,y_train)
fig, ax = plt.subplots(figsize=(100, 100))
plot_tree(xg_reg,ax=ax,num_trees=79)
plt.show()
# Out:
# [09:10:18] WARNING: C:/Jenkins/workspace/xgboost-win64_release_0.90/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
import pandas as pd
import numpy as np
df_train = pd.read_csv('train.csv')
X = df_train[['OverallQual', 'GrLivArea', 'GarageCars']].values.tolist()
Y = df_train['SalePrice'].values.tolist()

# %%
import random
X = [[random.randint(1,100)] for i in range(4)]
Y = random.sample(range(1,100),4)
print(X)
print(Y)
mdl = FractBoosting(1)
mdl.fit(X,Y,1,4)
mdl.print_trees()
# Out:
# [[70], [1], [30], [100]]
# [4, 7, 48, 13]
# itteration 1, mean loss: 16.436747
# itteration 2, mean loss: 6.246480
# itteration 3, mean loss: 3.415585
# 0th fractal tree
#
# -----------------
#
# S:
#
# ---1.000000
# -----------------
#
# T:
#
# ---18.000000
#
# -----------------
#
# 1th fractal tree
#
# -----------------
#
# S:
#
# ---1.000000
# -----------------
#
# T:
#
# ---X[0] >= 30.000000
# ------3.666667
# -------11.000000
#
# -----------------
#
# 2th fractal tree
#
# -----------------
#
# S:
#
# ---X[0] >= 30.000000
# ------1.333333
# -------0.000000
# -----------------
#
# T:
#
# ---X[0] >= 70.000000
# -------13.166667
# ------13.166667
#
# -----------------
#
# 3th fractal tree
#
# -----------------
#
# S:
#
# ---X[0] >= 70.000000
# ------0.900791
# ------1.519231
# -----------------
#
# T:
#
# ---X[0] >= 100.000000
# ------8.888889
# ------2.888889
#
# -----------------
